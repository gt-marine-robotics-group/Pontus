# %%
# First, confirm we are using a good GPU.

# !nvidia-smi
# Out:
# Mon Nov 13 06:03:40 2023
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 536.67                 Driver Version: 536.67       CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                     TCC/WDDM  | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce RTX 3060 ...  WDDM  | 00000000:01:00.0  On |                  N/A |
# | N/A   52C    P8              12W /  79W |    216MiB /  6144MiB |     10%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# Get current working directory, store in variable.

import os
HOME = os.getcwd()
print(HOME)
# Out:
# c:\Users\sabav\OneDrive\Documents\GitHub\Pontus\YOLOv8 Testing\MAKING MODEL\CUSTOM_DATASET

# %%
# Install YOLOv8 Library

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()

from ultralytics import YOLO

from IPython.display import display, Image
# Out:
# Ultralytics YOLOv8.0.93  Python-3.11.0 torch-2.1.0+cu118 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# Setup complete  (16 CPUs, 15.4 GB RAM, 686.3/953.6 GB disk)

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="bQiwasnMb87WCdeyuFmC")
project = rf.workspace("robosub-vto4l").project("gt-mrg-robosub-2023")
dataset = project.version(1).download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics<=8.0.20 is required but found version=8.0.93, to fix: `pip install ultralytics<=8.0.20`
# ...
# Extracting Dataset Version Zip to GT-MRG-ROBOSUB-2023-1 in yolov8:: 100%|██████████| 27000/27000 [00:12<00:00, 2216.48it/s]

# %%
# %cd {HOME}

model = YOLO('yolov8n.yaml')  # build a new model from YAML
results = model.train(data='C:\\Users\\sabav\\OneDrive\\Documents\\GitHub\\Pontus\\YOLOv8 Testing\\MAKING MODEL\\CUSTOM_DATASET\\GT-MRG-ROBOSUB-2023-1\\data.yaml', epochs=50, imgsz=720, patience=15, batch=-1, save_period=10, plots=True)
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.Conv                  [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.Conv                  [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.C2f                   [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.Conv                  [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.C2f                   [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.Conv                  [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.C2f                   [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.Conv                  [128, 256, 3, 2]
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('C:\\Users\\sabav\\OneDrive\\Documents\\GitHub\\Pontus\\YOLOv8 Testing\\MAKING MODEL\\CUSTOM_DATASET\\runs\detect\\train4\\weights\\last.pt')  # load a partially trained model

# Resume training
results = model.train(resume=True)
# Out:
# New https://pypi.org/project/ultralytics/8.0.208 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.93  Python-3.11.0 torch-2.1.0+cu118 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="bQiwasnMb87WCdeyuFmC")
project = rf.workspace("robosub-vto4l").project("gt-mrg-robosub-2023")

version = project.version(1)
version.deploy("yolov8n", "C:\\Users\sabav\\OneDrive\Documents\\GitHub\\Pontus\\YOLOv8 Testing\\MAKING MODEL\\CUSTOM_DATASET\\runs\\detect\\train4")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics<=8.0.20 is required but found version=8.0.93, to fix: `pip install ultralytics<=8.0.20`
# View the status of your deployment at: https://app.roboflow.com/robosub-vto4l/gt-mrg-robosub-2023/deploy/1
# Share your model with the world at: https://universe.roboflow.com/robosub-vto4l/gt-mrg-robosub-2023/model/1

# %%
from ultralytics import YOLO

# Load custom model
model = YOLO('.\\best.pt')  # Load a custom trained model

# Perform tracking with the model
results = model.track(source='C:\Users\sabav\Videos\Downloads\OneDrive_2023-11-12\RoboSub 2023 Data Sharing\Task 06_Engaging Chevrons _ Octagon\Task 06_Engaging Chevrons _ Octagon\Visual\TEAM FOLDER\CUAUV\octagon1.avi', show=True, stream=True, tracker='bytetrack.yaml', save=True)  # Tracking with default tracker
# results = model.track(source="https://youtu.be/LNwODJXcvt4", show=True, tracker="bytetrack.yaml")  # Tracking with ByteTrack tracker
